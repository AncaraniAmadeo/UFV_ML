# %% [markdown]
# ## Componentes de una Red Neuronal
#
# ### Resumen
# En este notebook vamos a ver en detalle los componentes de una red así como posibles mejoras diseñadas para problemas específicos. Veremos:
# - Funciones de activación
# - Redes convolucionales
# - Redes Recurrentes
# - Funciones loss, métricas y optimizadores
#
# Importamos los paquetes necesarios

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, Input, regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.losses import SparseCategoricalCrossentropy, MSE, MAE
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
import pandas as pd
from aux_func import show_history, r2_keras

# %% [markdown]
# Retomemos el problema del mnist

# %%
# %matplotlib inline
(X_train_mnist, y_train_mnist), (X_validation_mnist, y_validation_mnist) = mnist.load_data()

print('Número de elementos en el dataset = ',X_train_mnist.shape[0]+X_validation_mnist.shape[0])
plt.title('Número '+str(y_train_mnist[5]))
plt.imshow(X_train_mnist[5], cmap='Greys')
plt.show()
# Out:
# Número de elementos en el dataset =  70000

# %% [markdown]
# ### Deep Model
# Vamos a generar una red neuronal muy profunda para conseguir mejores resultados

# %%
# capas de la red
input = Input(shape=(28,28))
x = layers.Flatten()(input)
for i in range(20):
    x = layers.Dense(units=20, activation='sigmoid')(x)
output = layers.Dense(units=10, activation='softmax')(x)

# creamos el modelo
deep_model = Model(inputs=input, outputs=output)
print(deep_model.summary())

# optimizador
optimizer = SGD(learning_rate=0.01)

# función loss
loss = SparseCategoricalCrossentropy(from_logits=False)

# métrica
metrics = ['accuracy']

# compilamos el modelo
deep_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
# Out:
# Model: "functional_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_32 (InputLayer)        [(None, 28, 28)]          0
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_104 (Dense)            (None, 20)                15700
# _________________________________________________________________
# dense_105 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_106 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_107 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_108 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_109 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_110 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_111 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_112 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_113 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_114 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_115 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_116 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_117 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_118 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_119 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_120 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_121 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_122 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_123 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_124 (Dense)            (None, 10)                210
# =================================================================
# Total params: 23,890
# Trainable params: 23,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Entrenamos la red

# %%
history = deep_model.fit(x=X_train_mnist, y=y_train_mnist, batch_size=20, epochs=10,
                           validation_data=(X_validation_mnist, y_validation_mnist))
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 3s 996us/step - loss: 2.3092 - accuracy: 0.1082 - val_loss: 2.3029 - val_accuracy: 0.1135
# Epoch 2/10
# 3000/3000 [==============================] - 3s 913us/step - loss: 2.3022 - accuracy: 0.1103 - val_loss: 2.3020 - val_accuracy: 0.1135
# Epoch 3/10
# 3000/3000 [==============================] - 3s 944us/step - loss: 2.3019 - accuracy: 0.1111 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 4/10
# 3000/3000 [==============================] - 3s 898us/step - loss: 2.3018 - accuracy: 0.1098 - val_loss: 2.3021 - val_accuracy: 0.1028
# Epoch 5/10
# 3000/3000 [==============================] - 3s 942us/step - loss: 2.3021 - accuracy: 0.1111 - val_loss: 2.3021 - val_accuracy: 0.1010
# Epoch 6/10
# 3000/3000 [==============================] - 3s 886us/step - loss: 2.3020 - accuracy: 0.1105 - val_loss: 2.3016 - val_accuracy: 0.1135
# Epoch 7/10
# 3000/3000 [==============================] - 3s 891us/step - loss: 2.3019 - accuracy: 0.1103 - val_loss: 2.3017 - val_accuracy: 0.1135
# Epoch 8/10
# 3000/3000 [==============================] - 3s 879us/step - loss: 2.3019 - accuracy: 0.1115 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 9/10
# 3000/3000 [==============================] - 3s 882us/step - loss: 2.3020 - accuracy: 0.1110 - val_loss: 2.3026 - val_accuracy: 0.1135
# Epoch 10/10
# 3000/3000 [==============================] - 3s 892us/step - loss: 2.3021 - accuracy: 0.1106 - val_loss: 2.3027 - val_accuracy: 0.1135

# %% [markdown]
# Vemos como a pesar de ser una red con una capacidad de aprendizaje mucho mayor el score obtenido no es bueno. Es lo que se conoce como vanishing gradient problem.
#
# ### Relu
# Para solucionar este problema, una de las posibles opciones es utilizar funciones de activación lineales a trozos, como por ejemplo la función relu.

# %%
# capas de la red
input = Input(shape=(28,28))
x = layers.Flatten()(input)
for i in range(20):
    x = layers.Dense(units=20, activation='relu')(x)
output = layers.Dense(units=10, activation='softmax')(x)

# creamos el modelo
deep_model = Model(inputs=input, outputs=output)
print(deep_model.summary())

# compilamos el modelo
deep_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
# Out:
# Model: "functional_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_34 (InputLayer)        [(None, 28, 28)]          0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_146 (Dense)            (None, 20)                15700
# _________________________________________________________________
# dense_147 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_148 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_149 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_150 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_151 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_152 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_153 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_154 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_155 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_156 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_157 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_158 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_159 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_160 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_161 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_162 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_163 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_164 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_165 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_166 (Dense)            (None, 10)                210
# =================================================================
# Total params: 23,890
# Trainable params: 23,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
deep_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
history = deep_model.fit(x=X_train_mnist, y=y_train_mnist, batch_size=20, epochs=10,validation_data=(X_validation_mnist, y_validation_mnist))
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 4s 1ms/step - loss: 1.4096 - accuracy: 0.4415 - val_loss: 0.9621 - val_accuracy: 0.6025
# Epoch 2/10
# 3000/3000 [==============================] - 3s 959us/step - loss: 0.6879 - accuracy: 0.7804 - val_loss: 0.5642 - val_accuracy: 0.8202
# Epoch 3/10
# 3000/3000 [==============================] - 3s 954us/step - loss: 0.4648 - accuracy: 0.8741 - val_loss: 0.3824 - val_accuracy: 0.9026
# Epoch 4/10
# 3000/3000 [==============================] - 3s 958us/step - loss: 0.3775 - accuracy: 0.8997 - val_loss: 0.3359 - val_accuracy: 0.9178
# Epoch 5/10
# 3000/3000 [==============================] - 3s 914us/step - loss: 0.3584 - accuracy: 0.9033 - val_loss: 0.2901 - val_accuracy: 0.9222
# Epoch 6/10
# 3000/3000 [==============================] - 3s 907us/step - loss: 0.2869 - accuracy: 0.9238 - val_loss: 0.2867 - val_accuracy: 0.9207
# Epoch 7/10
# 3000/3000 [==============================] - 3s 881us/step - loss: 0.2802 - accuracy: 0.9262 - val_loss: 0.3083 - val_accuracy: 0.9226
# Epoch 8/10
# 3000/3000 [==============================] - 3s 872us/step - loss: 0.3058 - accuracy: 0.9204 - val_loss: 0.2524 - val_accuracy: 0.9355
# Epoch 9/10
# 3000/3000 [==============================] - 3s 890us/step - loss: 0.3011 - accuracy: 0.9189 - val_loss: 0.2947 - val_accuracy: 0.9215
# Epoch 10/10
# 3000/3000 [==============================] - 3s 883us/step - loss: 0.2588 - accuracy: 0.9310 - val_loss: 0.2595 - val_accuracy: 0.9314

# %%
show_history(history)

# %% [markdown]
# Elu
# Si utilizamos la función Elu obtenemos un resultado similar

# %%
# capas de la red
input = Input(shape=(28,28))
x = layers.Flatten()(input)
for i in range(20):
    x = layers.Dense(units=20, activation='elu')(x)
output = layers.Dense(units=10, activation='softmax')(x)

# creamos el modelo
deep_model = Model(inputs=input, outputs=output)
print(deep_model.summary())

# compilamos el modelo
deep_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
# Out:
# Model: "simple_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 20)                15700
# _________________________________________________________________
# dense_85 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_86 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_87 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_88 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_89 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_90 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_91 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_92 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_93 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_94 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_95 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_96 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_97 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_98 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_99 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_100 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_101 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_102 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_103 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_104 (Dense)            (None, 10)                210
# =================================================================
# Total params: 23,890
# Trainable params: 23,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = deep_model.fit(x=X_train_mnist, y=y_train_mnist, batch_size=20, epochs=10,validation_data=(X_validation_mnist, y_validation_mnist))
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 3s 956us/step - loss: 0.9248 - accuracy: 0.6963 - val_loss: 0.4365 - val_accuracy: 0.8823
# Epoch 2/10
# 3000/3000 [==============================] - 3s 845us/step - loss: 0.4000 - accuracy: 0.8968 - val_loss: 0.3274 - val_accuracy: 0.9142
# Epoch 3/10
# 3000/3000 [==============================] - 3s 892us/step - loss: 0.3160 - accuracy: 0.9171 - val_loss: 0.2862 - val_accuracy: 0.9246
# Epoch 4/10
# 3000/3000 [==============================] - 3s 903us/step - loss: 0.2937 - accuracy: 0.9228 - val_loss: 0.2663 - val_accuracy: 0.9289
# Epoch 5/10
# 3000/3000 [==============================] - 3s 907us/step - loss: 0.2641 - accuracy: 0.9308 - val_loss: 0.2579 - val_accuracy: 0.9302
# Epoch 6/10
# 3000/3000 [==============================] - 3s 954us/step - loss: 0.2416 - accuracy: 0.9359 - val_loss: 0.2386 - val_accuracy: 0.9365
# Epoch 7/10
# 3000/3000 [==============================] - 3s 873us/step - loss: 0.2527 - accuracy: 0.9334 - val_loss: 0.2740 - val_accuracy: 0.9276
# Epoch 8/10
# 3000/3000 [==============================] - 3s 928us/step - loss: 0.2381 - accuracy: 0.9363 - val_loss: 0.2394 - val_accuracy: 0.9381
# Epoch 9/10
# 3000/3000 [==============================] - 3s 908us/step - loss: 0.2224 - accuracy: 0.9409 - val_loss: 0.2240 - val_accuracy: 0.9414
# Epoch 10/10
# 3000/3000 [==============================] - 3s 861us/step - loss: 0.2501 - accuracy: 0.9321 - val_loss: 0.2319 - val_accuracy: 0.9382

# %% [markdown]
# ### Regresión
# Ahora, vamos a resolver un problema de regresión. Vamos a predecir el consumo de gasolina en función de ciertos parámetros del coche.

# %%
# obtenemos el dataset
dataset_path = tf.keras.utils.get_file("auto-mpg.data", "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']
raw_dataset = pd.read_csv(dataset_path, names=column_names,
                          na_values = "?", comment='\t',
                          sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()
print(dataset.tail())
dataset = dataset.dropna()
dataset = dataset.drop('Origin', 1)

# generamos el dataset de entrenamiento y validacion
X_train_consumo = dataset.sample(frac=0.8,random_state=0)
X_validation_consumo = dataset.drop(X_train_consumo.index)

y_train_consumo = X_train_consumo.pop('MPG')
y_validation_consumo = X_validation_consumo.pop('MPG')

# Normalizamos respecto de la media y varianza de los datos de train
train_mean, train_std = X_train_consumo.mean(), X_train_consumo.std()
X_train_consumo = (X_train_consumo-train_mean)/train_std
X_validation_consumo = (X_validation_consumo-train_mean)/train_std
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %% [markdown]
# Vamos a construir una red para este problema de regresión

# %%
# capas de la red
input = Input(shape=(6))
x = input
x = layers.Dense(units=200, activation='relu')(x)
x = layers.Dense(units=100, activation='relu')(x)
x = layers.Dense(units=50, activation='relu')(x)
x = layers.Dense(units=10, activation='relu')(x)

# no ponemos función de activación
output = layers.Dense(units=1, activation=None)(x)

# creamos el modelo
model = Model(inputs=input, outputs=output)
print(model.summary())

# compilamos el modelo
model.compile(optimizer=SGD(learning_rate=0.001), loss='mse', metrics=['mse', r2_keras])
# Out:
# Model: "functional_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_43 (InputLayer)        [(None, 6)]               0
# _________________________________________________________________
# dense_207 (Dense)            (None, 200)               1400
# _________________________________________________________________
# dense_208 (Dense)            (None, 100)               20100
# _________________________________________________________________
# dense_209 (Dense)            (None, 50)                5050
# _________________________________________________________________
# dense_210 (Dense)            (None, 10)                510
# _________________________________________________________________
# dense_211 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 27,071
# Trainable params: 27,071
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(x=X_train_consumo, y=y_train_consumo, batch_size=100, epochs=100,validation_data=(X_validation_consumo, y_validation_consumo))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 30ms/step - loss: 602.5728 - mse: 602.5728 - r2_keras: -11.0362 - val_loss: 625.6393 - val_mse: 625.6393 - val_r2_keras: -8.5800
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: 581.3476 - mse: 581.3476 - r2_keras: -9.2010 - val_loss: 591.6123 - val_mse: 591.6123 - val_r2_keras: -8.0590
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 541.4961 - mse: 541.4962 - r2_keras: -10.9474 - val_loss: 523.7532 - val_mse: 523.7532 - val_r2_keras: -7.0199
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 451.4237 - mse: 451.4237 - r2_keras: -6.1906 - val_loss: 258.5534 - val_mse: 258.5534 - val_r2_keras: -2.9591
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 131.7213 - mse: 131.7213 - r2_keras: -0.8284 - val_loss: 20.5466 - val_mse: 20.5466 - val_r2_keras: 0.6854
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 21.4049 - mse: 21.4049 - r2_keras: 0.6541 - val_loss: 17.1266 - val_mse: 17.1266 - val_r2_keras: 0.7378
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 17.8169 - mse: 17.8169 - r2_keras: 0.7215 - val_loss: 15.3288 - val_mse: 15.3288 - val_r2_keras: 0.7653
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 15.0185 - mse: 15.0185 - r2_keras: 0.7614 - val_loss: 11.5992 - val_mse: 11.5992 - val_r2_keras: 0.8224
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 13.7804 - mse: 13.7804 - r2_keras: 0.7665 - val_loss: 19.8590 - val_mse: 19.8590 - val_r2_keras: 0.6959
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 15.1818 - mse: 15.1818 - r2_keras: 0.7792 - val_loss: 11.4324 - val_mse: 11.4324 - val_r2_keras: 0.8249
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 11.3865 - mse: 11.3865 - r2_keras: 0.8337 - val_loss: 10.3406 - val_mse: 10.3406 - val_r2_keras: 0.8417
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 11.5063 - mse: 11.5063 - r2_keras: 0.8244 - val_loss: 8.6950 - val_mse: 8.6950 - val_r2_keras: 0.8669
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1763 - mse: 10.1763 - r2_keras: 0.8296 - val_loss: 10.1573 - val_mse: 10.1573 - val_r2_keras: 0.8445
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 10.0297 - mse: 10.0297 - r2_keras: 0.8426 - val_loss: 11.2838 - val_mse: 11.2838 - val_r2_keras: 0.8272
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1647 - mse: 10.1647 - r2_keras: 0.7988 - val_loss: 11.9743 - val_mse: 11.9743 - val_r2_keras: 0.8166
# Epoch 16/100
# 4/4 [==============================] - 0s 4ms/step - loss: 11.0641 - mse: 11.0641 - r2_keras: 0.7594 - val_loss: 9.3019 - val_mse: 9.3019 - val_r2_keras: 0.8576
# Epoch 17/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.3066 - mse: 9.3066 - r2_keras: 0.8581 - val_loss: 10.2916 - val_mse: 10.2916 - val_r2_keras: 0.8424
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.0970 - mse: 9.0970 - r2_keras: 0.8549 - val_loss: 8.6189 - val_mse: 8.6189 - val_r2_keras: 0.8680
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.2985 - mse: 9.2985 - r2_keras: 0.7960 - val_loss: 8.0300 - val_mse: 8.0300 - val_r2_keras: 0.8770
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.7340 - mse: 8.7340 - r2_keras: 0.8581 - val_loss: 11.1007 - val_mse: 11.1007 - val_r2_keras: 0.8300
# Epoch 21/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.7375 - mse: 9.7375 - r2_keras: 0.8413 - val_loss: 8.4481 - val_mse: 8.4481 - val_r2_keras: 0.8706
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.0529 - mse: 9.0529 - r2_keras: 0.8615 - val_loss: 8.1369 - val_mse: 8.1369 - val_r2_keras: 0.8754
# Epoch 23/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.2580 - mse: 9.2580 - r2_keras: 0.8244 - val_loss: 7.7011 - val_mse: 7.7011 - val_r2_keras: 0.8821
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.3477 - mse: 8.3477 - r2_keras: 0.8586 - val_loss: 7.3706 - val_mse: 7.3706 - val_r2_keras: 0.8871
# Epoch 25/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.3617 - mse: 8.3617 - r2_keras: 0.8482 - val_loss: 7.5765 - val_mse: 7.5765 - val_r2_keras: 0.8840
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.2052 - mse: 9.2052 - r2_keras: 0.8645 - val_loss: 7.4544 - val_mse: 7.4544 - val_r2_keras: 0.8859
# Epoch 27/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2485 - mse: 8.2485 - r2_keras: 0.8771 - val_loss: 7.3374 - val_mse: 7.3374 - val_r2_keras: 0.8876
# Epoch 28/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.3444 - mse: 8.3444 - r2_keras: 0.8333 - val_loss: 10.2406 - val_mse: 10.2406 - val_r2_keras: 0.8432
# Epoch 29/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9299 - mse: 8.9299 - r2_keras: 0.8588 - val_loss: 10.2221 - val_mse: 10.2221 - val_r2_keras: 0.8435
# Epoch 30/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8407 - mse: 8.8407 - r2_keras: 0.8316 - val_loss: 9.5584 - val_mse: 9.5584 - val_r2_keras: 0.8536
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9916 - mse: 8.9916 - r2_keras: 0.8384 - val_loss: 8.7994 - val_mse: 8.7994 - val_r2_keras: 0.8653
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2214 - mse: 8.2214 - r2_keras: 0.8286 - val_loss: 8.7963 - val_mse: 8.7963 - val_r2_keras: 0.8653
# Epoch 33/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.6861 - mse: 9.6861 - r2_keras: 0.7846 - val_loss: 7.8434 - val_mse: 7.8434 - val_r2_keras: 0.8799
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.7997 - mse: 8.7997 - r2_keras: 0.8374 - val_loss: 7.7404 - val_mse: 7.7404 - val_r2_keras: 0.8815
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.8390 - mse: 7.8390 - r2_keras: 0.8507 - val_loss: 7.7964 - val_mse: 7.7964 - val_r2_keras: 0.8806
# Epoch 36/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.0415 - mse: 8.0415 - r2_keras: 0.8582 - val_loss: 7.2629 - val_mse: 7.2629 - val_r2_keras: 0.8888
# Epoch 37/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.6791 - mse: 7.6791 - r2_keras: 0.8741 - val_loss: 7.0471 - val_mse: 7.0471 - val_r2_keras: 0.8921
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.8326 - mse: 7.8326 - r2_keras: 0.8312 - val_loss: 7.5457 - val_mse: 7.5457 - val_r2_keras: 0.8845
# Epoch 39/100
# 4/4 [==============================] - 0s 5ms/step - loss: 8.0928 - mse: 8.0928 - r2_keras: 0.8338 - val_loss: 11.2073 - val_mse: 11.2073 - val_r2_keras: 0.8284
# Epoch 40/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.7585 - mse: 8.7585 - r2_keras: 0.8514 - val_loss: 8.4469 - val_mse: 8.4469 - val_r2_keras: 0.8707
# Epoch 41/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7147 - mse: 7.7147 - r2_keras: 0.8655 - val_loss: 8.0150 - val_mse: 8.0150 - val_r2_keras: 0.8773
# Epoch 42/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.6159 - mse: 8.6159 - r2_keras: 0.8610 - val_loss: 7.3036 - val_mse: 7.3036 - val_r2_keras: 0.8882
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5885 - mse: 7.5885 - r2_keras: 0.8313 - val_loss: 6.9781 - val_mse: 6.9781 - val_r2_keras: 0.8931
# Epoch 44/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5624 - mse: 7.5624 - r2_keras: 0.8623 - val_loss: 11.6961 - val_mse: 11.6961 - val_r2_keras: 0.8209
# Epoch 45/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.0378 - mse: 8.0378 - r2_keras: 0.8547 - val_loss: 6.9502 - val_mse: 6.9502 - val_r2_keras: 0.8936
# Epoch 46/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.4351 - mse: 7.4351 - r2_keras: 0.8844 - val_loss: 10.3943 - val_mse: 10.3943 - val_r2_keras: 0.8408
# Epoch 47/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.8377 - mse: 7.8377 - r2_keras: 0.8668 - val_loss: 7.0946 - val_mse: 7.0946 - val_r2_keras: 0.8914
# Epoch 48/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.6850 - mse: 7.6850 - r2_keras: 0.8849 - val_loss: 8.8458 - val_mse: 8.8458 - val_r2_keras: 0.8645
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7767 - mse: 7.7767 - r2_keras: 0.8756 - val_loss: 7.7833 - val_mse: 7.7833 - val_r2_keras: 0.8808
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7606 - mse: 7.7606 - r2_keras: 0.8575 - val_loss: 7.2082 - val_mse: 7.2082 - val_r2_keras: 0.8896
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3253 - mse: 7.3253 - r2_keras: 0.8875 - val_loss: 8.0680 - val_mse: 8.0680 - val_r2_keras: 0.8765
# Epoch 52/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4320 - mse: 8.4320 - r2_keras: 0.8610 - val_loss: 9.5452 - val_mse: 9.5452 - val_r2_keras: 0.8538
# Epoch 53/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.3002 - mse: 8.3002 - r2_keras: 0.8702 - val_loss: 10.6792 - val_mse: 10.6792 - val_r2_keras: 0.8365
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.1700 - mse: 8.1700 - r2_keras: 0.8369 - val_loss: 36.8671 - val_mse: 36.8671 - val_r2_keras: 0.4355
# Epoch 55/100
# 4/4 [==============================] - 0s 4ms/step - loss: 17.4578 - mse: 17.4578 - r2_keras: 0.7348 - val_loss: 7.0593 - val_mse: 7.0593 - val_r2_keras: 0.8919
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.4407 - mse: 7.4407 - r2_keras: 0.8892 - val_loss: 6.9428 - val_mse: 6.9428 - val_r2_keras: 0.8937
# Epoch 57/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.2337 - mse: 7.2337 - r2_keras: 0.8781 - val_loss: 16.4512 - val_mse: 16.4512 - val_r2_keras: 0.7481
# Epoch 58/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.5349 - mse: 9.5349 - r2_keras: 0.8273 - val_loss: 7.8176 - val_mse: 7.8176 - val_r2_keras: 0.8803
# Epoch 59/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.6929 - mse: 7.6929 - r2_keras: 0.8635 - val_loss: 7.1815 - val_mse: 7.1815 - val_r2_keras: 0.8900
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7137 - mse: 7.7137 - r2_keras: 0.8717 - val_loss: 8.1353 - val_mse: 8.1353 - val_r2_keras: 0.8754
# Epoch 61/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5640 - mse: 7.5640 - r2_keras: 0.8799 - val_loss: 7.0425 - val_mse: 7.0425 - val_r2_keras: 0.8922
# Epoch 62/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5963 - mse: 7.5963 - r2_keras: 0.8624 - val_loss: 7.1055 - val_mse: 7.1055 - val_r2_keras: 0.8912
# Epoch 63/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.1182 - mse: 7.1182 - r2_keras: 0.8759 - val_loss: 6.8993 - val_mse: 6.8993 - val_r2_keras: 0.8944
# Epoch 64/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0032 - mse: 7.0032 - r2_keras: 0.8506 - val_loss: 6.7822 - val_mse: 6.7822 - val_r2_keras: 0.8961
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3923 - mse: 7.3923 - r2_keras: 0.8884 - val_loss: 7.3382 - val_mse: 7.3382 - val_r2_keras: 0.8876
# Epoch 66/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.9912 - mse: 6.9912 - r2_keras: 0.8934 - val_loss: 11.4600 - val_mse: 11.4600 - val_r2_keras: 0.8245
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8770 - mse: 8.8770 - r2_keras: 0.8674 - val_loss: 10.5201 - val_mse: 10.5201 - val_r2_keras: 0.8389
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.6867 - mse: 7.6867 - r2_keras: 0.8670 - val_loss: 6.9987 - val_mse: 6.9987 - val_r2_keras: 0.8928
# Epoch 69/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.4475 - mse: 7.4475 - r2_keras: 0.8861 - val_loss: 7.0723 - val_mse: 7.0723 - val_r2_keras: 0.8917
# Epoch 70/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0822 - mse: 7.0822 - r2_keras: 0.8709 - val_loss: 8.4437 - val_mse: 8.4437 - val_r2_keras: 0.8707
# Epoch 71/100
# 4/4 [==============================] - 0s 4ms/step - loss: 9.0302 - mse: 9.0302 - r2_keras: 0.8569 - val_loss: 7.2398 - val_mse: 7.2398 - val_r2_keras: 0.8891
# Epoch 72/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9326 - mse: 8.9326 - r2_keras: 0.8204 - val_loss: 7.0266 - val_mse: 7.0266 - val_r2_keras: 0.8924
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0617 - mse: 7.0617 - r2_keras: 0.8839 - val_loss: 11.1753 - val_mse: 11.1753 - val_r2_keras: 0.8289
# Epoch 74/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.6079 - mse: 8.6079 - r2_keras: 0.8349 - val_loss: 7.0121 - val_mse: 7.0121 - val_r2_keras: 0.8926
# Epoch 75/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.8920 - mse: 6.8920 - r2_keras: 0.8878 - val_loss: 6.7445 - val_mse: 6.7445 - val_r2_keras: 0.8967
# Epoch 76/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.2334 - mse: 8.2334 - r2_keras: 0.8642 - val_loss: 6.9513 - val_mse: 6.9513 - val_r2_keras: 0.8936
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 7.2109 - mse: 7.2109 - r2_keras: 0.8661 - val_loss: 8.2391 - val_mse: 8.2391 - val_r2_keras: 0.8738
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.6858 - mse: 7.6858 - r2_keras: 0.8672 - val_loss: 22.2247 - val_mse: 22.2247 - val_r2_keras: 0.6597
# Epoch 79/100
# 4/4 [==============================] - 0s 4ms/step - loss: 15.4243 - mse: 15.4243 - r2_keras: 0.7777 - val_loss: 6.6105 - val_mse: 6.6105 - val_r2_keras: 0.8988
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.7860 - mse: 6.7860 - r2_keras: 0.8916 - val_loss: 6.4409 - val_mse: 6.4409 - val_r2_keras: 0.9014
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.1349 - mse: 7.1349 - r2_keras: 0.8631 - val_loss: 6.9254 - val_mse: 6.9254 - val_r2_keras: 0.8940
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.8349 - mse: 6.8349 - r2_keras: 0.8980 - val_loss: 8.1103 - val_mse: 8.1103 - val_r2_keras: 0.8758
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3699 - mse: 7.3699 - r2_keras: 0.8751 - val_loss: 9.2255 - val_mse: 9.2255 - val_r2_keras: 0.8587
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.6170 - mse: 7.6170 - r2_keras: 0.8837 - val_loss: 7.0064 - val_mse: 7.0064 - val_r2_keras: 0.8927
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.1051 - mse: 7.1051 - r2_keras: 0.8910 - val_loss: 6.9832 - val_mse: 6.9832 - val_r2_keras: 0.8931
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.7383 - mse: 6.7383 - r2_keras: 0.8983 - val_loss: 6.9632 - val_mse: 6.9632 - val_r2_keras: 0.8934
# Epoch 87/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3755 - mse: 7.3755 - r2_keras: 0.8845 - val_loss: 7.1277 - val_mse: 7.1277 - val_r2_keras: 0.8909
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.0664 - mse: 7.0664 - r2_keras: 0.8718 - val_loss: 11.9160 - val_mse: 11.9160 - val_r2_keras: 0.8175
# Epoch 89/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7876 - mse: 7.7876 - r2_keras: 0.8747 - val_loss: 6.6456 - val_mse: 6.6456 - val_r2_keras: 0.8982
# Epoch 90/100
# 4/4 [==============================] - 0s 4ms/step - loss: 7.2543 - mse: 7.2543 - r2_keras: 0.8660 - val_loss: 10.8330 - val_mse: 10.8330 - val_r2_keras: 0.8341
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4455 - mse: 8.4455 - r2_keras: 0.8610 - val_loss: 7.9444 - val_mse: 7.9444 - val_r2_keras: 0.8784
# Epoch 92/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.0222 - mse: 8.0222 - r2_keras: 0.8678 - val_loss: 6.7302 - val_mse: 6.7302 - val_r2_keras: 0.8969
# Epoch 93/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.7500 - mse: 6.7500 - r2_keras: 0.8736 - val_loss: 9.5002 - val_mse: 9.5002 - val_r2_keras: 0.8545
# Epoch 94/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.1239 - mse: 8.1239 - r2_keras: 0.8666 - val_loss: 7.6098 - val_mse: 7.6098 - val_r2_keras: 0.8835
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 8.9915 - mse: 8.9915 - r2_keras: 0.8552 - val_loss: 6.5362 - val_mse: 6.5362 - val_r2_keras: 0.8999
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.9547 - mse: 6.9547 - r2_keras: 0.8862 - val_loss: 6.3400 - val_mse: 6.3400 - val_r2_keras: 0.9029
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.6337 - mse: 6.6337 - r2_keras: 0.8978 - val_loss: 6.5624 - val_mse: 6.5624 - val_r2_keras: 0.8995
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.9924 - mse: 6.9924 - r2_keras: 0.8686 - val_loss: 37.0672 - val_mse: 37.0672 - val_r2_keras: 0.4324
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 15.8681 - mse: 15.8681 - r2_keras: 0.7676 - val_loss: 6.5896 - val_mse: 6.5896 - val_r2_keras: 0.8991
# Epoch 100/100
# 4/4 [==============================] - 0s 4ms/step - loss: 6.6514 - mse: 6.6514 - r2_keras: 0.8798 - val_loss: 7.0695 - val_mse: 7.0695 - val_r2_keras: 0.8917

# %% [markdown]
# Veamos la evolución del loss y la metrica

# %%
show_history(history, metrics=['mse', 'r2_keras'])

# %% [markdown]
# ¿Que pasa si ponemos el LR=1?

# %% [markdown]
# ### Redes Convolucionales
# Vamos de ver como implementar redes convolucionales para el análisis de imágenes
# Trabajaremos con el dataset CIFAR 10

# %%
from tensorflow.keras.datasets import cifar10

(X_train_cifar10, y_train_cifar10), (X_validation_cifar10, y_validation_cifar10) = cifar10.load_data()
X_train_cifar10 = X_train_cifar10/255
X_validation_cifar10 = X_validation_cifar10/255

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
# capas de la red
input = Input(shape=(32,32,3))
layer = Conv2D(filters=20, kernel_size=3, strides=1, padding='same', activation='relu')(input)
layer = MaxPooling2D((2, 2))(layer)
layer = Conv2D(filters=40, kernel_size=3, strides=1, padding='same', activation='relu')(layer)
layer = MaxPooling2D((2, 2))(layer)
layer = Conv2D(filters=80, kernel_size=3, strides=1, padding='same', activation='relu')(layer)
layer = MaxPooling2D((2, 2))(layer)
layer = Flatten()(layer)
layer = Dense(units=200, activation='relu')(layer)
output = Dense(units=10, activation='softmax')(layer)

# creamos el modelo
model = Model(inputs=input, outputs=output)
print(model.summary())

# optimizador
optimizer = SGD(learning_rate=0.01)

# función loss
loss = SparseCategoricalCrossentropy(from_logits=False)

# métrica
metrics = ['accuracy']

# compilamos el modelo
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(x=X_train_cifar10, y=y_train_cifar10, batch_size=30, epochs=20,
                    validation_data=(X_validation_cifar10, y_validation_cifar10))
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 20)        560
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 20)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 40)        7240
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 40)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 80)          28880
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 80)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               256200
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                2010
# =================================================================
# Total params: 294,890
# Trainable params: 294,890
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 1667/1667 [==============================] - 24s 14ms/step - loss: 2.0010 - accuracy: 0.2769 - val_loss: 1.7189 - val_accuracy: 0.3942
# Epoch 2/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 1.6147 - accuracy: 0.4220 - val_loss: 1.4890 - val_accuracy: 0.4732
# Epoch 3/20
# 1667/1667 [==============================] - 29s 18ms/step - loss: 1.4318 - accuracy: 0.4882 - val_loss: 1.3472 - val_accuracy: 0.5190
# Epoch 4/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 1.3136 - accuracy: 0.5327 - val_loss: 1.3047 - val_accuracy: 0.5450
# Epoch 5/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 1.2089 - accuracy: 0.5711 - val_loss: 1.2680 - val_accuracy: 0.5482
# Epoch 6/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 1.1248 - accuracy: 0.6051 - val_loss: 1.1018 - val_accuracy: 0.6140
# Epoch 7/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 1.0507 - accuracy: 0.6314 - val_loss: 1.1106 - val_accuracy: 0.6065
# Epoch 8/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.9893 - accuracy: 0.6545 - val_loss: 1.0610 - val_accuracy: 0.6198
# Epoch 9/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.9314 - accuracy: 0.6746 - val_loss: 0.9821 - val_accuracy: 0.6546
# Epoch 10/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.8827 - accuracy: 0.6923 - val_loss: 0.9909 - val_accuracy: 0.6521
# Epoch 11/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.8376 - accuracy: 0.7092 - val_loss: 0.9692 - val_accuracy: 0.6621
# Epoch 12/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.7951 - accuracy: 0.7229 - val_loss: 0.9926 - val_accuracy: 0.6581
# Epoch 13/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.7550 - accuracy: 0.7391 - val_loss: 0.9074 - val_accuracy: 0.6896
# Epoch 14/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.7146 - accuracy: 0.7546 - val_loss: 0.9155 - val_accuracy: 0.6876
# Epoch 15/20
# 1667/1667 [==============================] - 31s 18ms/step - loss: 0.6838 - accuracy: 0.7635 - val_loss: 0.9107 - val_accuracy: 0.6907
# Epoch 16/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.6444 - accuracy: 0.7782 - val_loss: 0.8827 - val_accuracy: 0.7030
# Epoch 17/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.6092 - accuracy: 0.7892 - val_loss: 1.0297 - val_accuracy: 0.6739
# Epoch 18/20
# 1667/1667 [==============================] - 30s 18ms/step - loss: 0.5762 - accuracy: 0.8008 - val_loss: 0.9177 - val_accuracy: 0.6955
# Epoch 19/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.5413 - accuracy: 0.8119 - val_loss: 0.9050 - val_accuracy: 0.7091
# Epoch 20/20
# 1667/1667 [==============================] - 29s 18ms/step - loss: 0.5104 - accuracy: 0.8234 - val_loss: 0.9625 - val_accuracy: 0.6952

# %% [markdown]
# Veamos la evolución de los scores durante el entrenamiento

# %%
show_history(history)

# %% [markdown]
# Parece que el modelo puede seguir mejorando, aunque empieza a presentar signos de overfiting.
# Veamos cual es la confusion matrix.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.argmax(model.predict(X_validation_cifar10), axis=-1)

plt.figure(figsize=(10, 10))
cm = confusion_matrix(y_true=y_validation_cifar10, y_pred=y_pred, normalize='true', labels=range(10))
cm = np.around(cm, decimals=2)
ax = plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax)  # annot=True to annotate cells, ftm='g' to disable scientific notation
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'], rotation=45)
ax.yaxis.set_ticklabels(['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'], rotation=45)
plt.show()

# %% [markdown]
# Probar en Google Colab:
# - Cambiar las funciones de activación.
# - Poner más filtros y neuronas.
# - Probar a cambiar el maxpooling, los strides y el padding.

# %% [markdown]
# ### Redes Recurrentes
# En este apartado veremos como procesar datos, en particular una series temporal, con redes recurrentes.
# Empecemos trabajando con el valor del bitcoin.

# %%
# Vamos a cargar el dataset
import pandas as pd

# Dataset del valor del bitcoin por minuto
data = pd.read_csv('./data/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')
data = np.array(data.Close.fillna(method='ffill'))[-2000000:-1000000]

# ploteamos los datos
plt.plot(data[::1000])
plt.title('Bitcoin')
plt.show()

# cuidado al hacer el split!!
data_train = data[:int(data.shape[0] * 0.6)]
data_test = data[int(data.shape[0] * 0.6):]

# %%
# Parámetros creación del dataset
# Longitud de la serie
w_size = 500

# Tiempo a futuro en el que predecimos
off_set = 10

# Función para generar un batch de elementos
# El generador que nos devuelve se lo pasaremos al método fit para entrenar
def get_bach(data, batch_size=500):
    while True:
        # seleccionamos unos cuantos índices aleatorios
        indexs = np.random.randint(0, data.shape[0] - w_size - off_set, batch_size)

        # generamos el batch
        X_bach = [data[x:x + w_size] for x in indexs]
        y_bach = data[indexs + w_size + off_set]

        # stackeamos
        X_bach = np.stack(X_bach, axis=0)
        y_bach = np.stack(y_bach, axis=0)


        # Cálculo del valor respecto del último valor obtenido
        y_bach = y_bach- X_bach[:, -1]
        X_bach = X_bach-X_bach[:,-1].reshape(-1,1)
        yield X_bach, y_bach

# Generamos un ejemplo de los elementos del dataset
a = get_bach(data_train, batch_size=3)
for _ in range(5):
    x, y = next(a)
    plt.plot(x[0, :])
    plt.show()

# %% [markdown]
# Creamos la red recurrente usando módulos LSTM con memoria a largo plazo

# %%
from tensorflow.keras.layers import LSTM, Dense
from aux_func import r2_keras

input_tensor = Input(shape=(w_size), dtype='float32')
x_0 = input_tensor

# Expandimos la dimensión de las features, el formato de entrada es (batch, time_steps, features)
x = tf.expand_dims(x_0, axis=-1)

for _ in range(3):
    x = LSTM(30, activation='tanh', recurrent_activation='sigmoid', return_sequences=True)(x)
x = LSTM(50, activation='tanh', recurrent_activation='sigmoid', return_sequences=False)(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation=tf.nn.leaky_relu)(x)
x = layers.Dense(100, activation=tf.nn.leaky_relu)(x)
x = layers.Dense(1, activation=None)(x)

model = Model(input_tensor, x)
print(model.summary())

# compilamos el modelo con varias métricas
model.compile(optimizer=tf.keras.optimizers.Adam(0.0001), loss='mse',metrics=['mse', 'mean_absolute_error',r2_keras])
# Out:
# Model: "functional_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        [(None, 500)]             0
# _________________________________________________________________
# tf_op_layer_ExpandDims_26 (T [(None, 500, 1)]          0
# _________________________________________________________________
# lstm_107 (LSTM)              (None, 500, 30)           3840
# _________________________________________________________________
# lstm_108 (LSTM)              (None, 500, 30)           7320
# _________________________________________________________________
# lstm_109 (LSTM)              (None, 500, 30)           7320
# _________________________________________________________________
# lstm_110 (LSTM)              (None, 50)                16200
# _________________________________________________________________
# flatten_25 (Flatten)         (None, 50)                0
# _________________________________________________________________
# dense_71 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_72 (Dense)             (None, 100)               25700
# _________________________________________________________________
# dense_73 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 73,537
# Trainable params: 73,537
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Ahora tenemos que generar los dataset dinámicos para el entrenamiento
train_generator = get_bach(data_train, batch_size=100)
test_generator = get_bach(data_test, batch_size=100)

# Entrenamos el modelo con dichos generadores
history = model.fit(train_generator, epochs=5, steps_per_epoch=200, shuffle=False,
                    callbacks=[], verbose=1, validation_data=test_generator,validation_steps=10)
# Out:
# Epoch 1/5
# 200/200 [==============================] - 136s 681ms/step - loss: 2501.0273 - mse: 2501.0273 - mean_absolute_error: 26.4485 - r2_keras: -0.0082 - val_loss: 195.0276 - val_mse: 195.0275 - val_mean_absolute_error: 7.4681 - val_r2_keras: -0.0090
# Epoch 2/5
# 200/200 [==============================] - 147s 736ms/step - loss: 2406.2007 - mse: 2406.2007 - mean_absolute_error: 26.1311 - r2_keras: -0.0089 - val_loss: 214.8635 - val_mse: 214.8635 - val_mean_absolute_error: 7.2959 - val_r2_keras: -0.0211
# Epoch 3/5
# 200/200 [==============================] - 137s 687ms/step - loss: 2652.7336 - mse: 2652.7336 - mean_absolute_error: 26.5191 - r2_keras: -0.0097 - val_loss: 167.7270 - val_mse: 167.7270 - val_mean_absolute_error: 7.2421 - val_r2_keras: -0.0057
# Epoch 4/5
# 200/200 [==============================] - 130s 652ms/step - loss: 2615.1074 - mse: 2615.1074 - mean_absolute_error: 26.7561 - r2_keras: -0.0097 - val_loss: 191.8880 - val_mse: 191.8880 - val_mean_absolute_error: 7.5575 - val_r2_keras: -0.0089
# Epoch 5/5
# 200/200 [==============================] - 131s 657ms/step - loss: 2505.2358 - mse: 2505.2358 - mean_absolute_error: 26.3843 - r2_keras: -0.0090 - val_loss: 180.6920 - val_mse: 180.6920 - val_mean_absolute_error: 7.4007 - val_r2_keras: 0.0084

# %% [markdown]
# El modelo no consigue obtener buenos resultados. El R2 score es casi 0. ¿Por que?
# Probar en Google Colab:
# - Generar un modelo de clasificación con capas recurrentes para predecir si el precio sube o baja
# - Probar a cambiar el tamaño de la ventana y el tiempo futuro de predicción
# - Cambiar la arquitectura de la red para intentar obtener un score R2 > 0
#
# Trabajemos ahora con un dataset sintético.

# %%
# Esta función genera una serie temporal seudo aleatoria con cierta periodicidad
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# Generamos train, validation y test
n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train_sequence, y_train_sequence = series[:7000, :n_steps], series[:7000, -1]
X_valid_sequence, y_valid_sequence = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test_sequence, y_test_sequence = series[9000:, :n_steps], series[9000:, -1]


# Función para plotear
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$", legend=True):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bo", label="Target")
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "rx", markersize=10, label="Prediction")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])
    if legend and (y or y_pred):
        plt.legend(fontsize=14, loc="upper left")

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid_sequence[col, :, 0], y_valid_sequence[col, 0],
                y_label=("$x(t)$" if col==0 else None),
                legend=(col == 0))
plt.show()

# %% [markdown]
# Creamos un modelo con módulos LSTM

# %%
input_tensor = Input(shape=(n_steps), dtype='float32')
x_0 = input_tensor
x = tf.expand_dims(x_0, axis=-1)

# Dependiendo de cual sea el output deberemos cambiar el valor 'return_sequences'
for _ in range(5):
    x = LSTM(100, activation='tanh', recurrent_activation='sigmoid', return_sequences=True)(x)
x = LSTM(200, activation='tanh', recurrent_activation='sigmoid', return_sequences=False)(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation=tf.nn.leaky_relu)(x)
x = layers.Dense(100, activation=tf.nn.leaky_relu)(x)
x = layers.Dense(1, activation=None)(x)

model = Model(input_tensor, x)
print(model.summary())

model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='mse',metrics=['mse', 'mean_absolute_error',r2_keras])
history = model.fit(X_train_sequence,y_train_sequence, epochs=20, batch_size=30, steps_per_epoch=200, shuffle=False,
                    callbacks=[], verbose=1, validation_data=(X_valid_sequence, y_valid_sequence),validation_steps=10)
# Out:
# Model: "functional_81"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_44 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# tf_op_layer_ExpandDims_30 (T [(None, 50, 1)]           0
# _________________________________________________________________
# lstm_126 (LSTM)              (None, 50, 100)           40800
# _________________________________________________________________
# lstm_127 (LSTM)              (None, 50, 100)           80400
# _________________________________________________________________
# lstm_128 (LSTM)              (None, 50, 100)           80400
# _________________________________________________________________
# lstm_129 (LSTM)              (None, 50, 100)           80400
# _________________________________________________________________
# lstm_130 (LSTM)              (None, 50, 100)           80400
# _________________________________________________________________
# lstm_131 (LSTM)              (None, 200)               240800
# _________________________________________________________________
# flatten_33 (Flatten)         (None, 200)               0
# _________________________________________________________________
# dense_212 (Dense)            (None, 256)               51456
# _________________________________________________________________
# dense_213 (Dense)            (None, 100)               25700
# _________________________________________________________________
# dense_214 (Dense)            (None, 1)                 101
# =================================================================
# Total params: 680,457
# Trainable params: 680,457
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 200/200 [==============================] - 26s 132ms/step - loss: 0.0366 - mse: 0.0366 - mean_absolute_error: 0.1503 - r2_keras: 0.7305 - val_loss: 0.0224 - val_mse: 0.0224 - val_mean_absolute_error: 0.1249 - val_r2_keras: 0.8363
# Epoch 2/20
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0189 - mse: 0.0189 - mean_absolute_error: 0.1135 - r2_keras: 0.8609 - val_loss: 0.0241 - val_mse: 0.0241 - val_mean_absolute_error: 0.1240 - val_r2_keras: 0.8237
# Epoch 3/20
# 200/200 [==============================] - 25s 124ms/step - loss: 0.0170 - mse: 0.0170 - mean_absolute_error: 0.1064 - r2_keras: 0.8762 - val_loss: 0.0173 - val_mse: 0.0173 - val_mean_absolute_error: 0.1091 - val_r2_keras: 0.8718
# Epoch 4/20
# 200/200 [==============================] - 24s 122ms/step - loss: 0.0157 - mse: 0.0157 - mean_absolute_error: 0.1022 - r2_keras: 0.8847 - val_loss: 0.0147 - val_mse: 0.0147 - val_mean_absolute_error: 0.1000 - val_r2_keras: 0.8902
# Epoch 5/20
# 200/200 [==============================] - 24s 120ms/step - loss: 0.0128 - mse: 0.0128 - mean_absolute_error: 0.0911 - r2_keras: 0.9061 - val_loss: 0.0098 - val_mse: 0.0098 - val_mean_absolute_error: 0.0814 - val_r2_keras: 0.9289
# Epoch 6/20
# 200/200 [==============================] - 25s 127ms/step - loss: 0.0109 - mse: 0.0109 - mean_absolute_error: 0.0838 - r2_keras: 0.9210 - val_loss: 0.0084 - val_mse: 0.0084 - val_mean_absolute_error: 0.0741 - val_r2_keras: 0.9385
# Epoch 7/20
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0079 - mse: 0.0079 - mean_absolute_error: 0.0706 - r2_keras: 0.9430 - val_loss: 0.0074 - val_mse: 0.0074 - val_mean_absolute_error: 0.0697 - val_r2_keras: 0.9455
# Epoch 8/20
# 200/200 [==============================] - 25s 124ms/step - loss: 0.0048 - mse: 0.0048 - mean_absolute_error: 0.0553 - r2_keras: 0.9648 - val_loss: 0.0038 - val_mse: 0.0038 - val_mean_absolute_error: 0.0502 - val_r2_keras: 0.9711
# Epoch 9/20
# 200/200 [==============================] - 25s 123ms/step - loss: 0.0035 - mse: 0.0035 - mean_absolute_error: 0.0474 - r2_keras: 0.9742 - val_loss: 0.0028 - val_mse: 0.0028 - val_mean_absolute_error: 0.0435 - val_r2_keras: 0.9792
# Epoch 10/20
# 200/200 [==============================] - 24s 121ms/step - loss: 0.0030 - mse: 0.0030 - mean_absolute_error: 0.0441 - r2_keras: 0.9780 - val_loss: 0.0025 - val_mse: 0.0025 - val_mean_absolute_error: 0.0415 - val_r2_keras: 0.9812
# Epoch 11/20
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0028 - mse: 0.0028 - mean_absolute_error: 0.0428 - r2_keras: 0.9792 - val_loss: 0.0026 - val_mse: 0.0026 - val_mean_absolute_error: 0.0413 - val_r2_keras: 0.9802
# Epoch 12/20
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0027 - mse: 0.0027 - mean_absolute_error: 0.0420 - r2_keras: 0.9800 - val_loss: 0.0034 - val_mse: 0.0034 - val_mean_absolute_error: 0.0466 - val_r2_keras: 0.9749
# Epoch 13/20
# 200/200 [==============================] - 25s 124ms/step - loss: 0.0027 - mse: 0.0027 - mean_absolute_error: 0.0422 - r2_keras: 0.9802 - val_loss: 0.0033 - val_mse: 0.0033 - val_mean_absolute_error: 0.0455 - val_r2_keras: 0.9754
# Epoch 14/20
# 200/200 [==============================] - 27s 133ms/step - loss: 0.0027 - mse: 0.0027 - mean_absolute_error: 0.0422 - r2_keras: 0.9801 - val_loss: 0.0028 - val_mse: 0.0028 - val_mean_absolute_error: 0.0430 - val_r2_keras: 0.9786
# Epoch 15/20
# 200/200 [==============================] - 24s 120ms/step - loss: 0.0027 - mse: 0.0027 - mean_absolute_error: 0.0419 - r2_keras: 0.9802 - val_loss: 0.0024 - val_mse: 0.0024 - val_mean_absolute_error: 0.0395 - val_r2_keras: 0.9818
# Epoch 16/20
# 200/200 [==============================] - 26s 129ms/step - loss: 0.0026 - mse: 0.0026 - mean_absolute_error: 0.0412 - r2_keras: 0.9806 - val_loss: 0.0027 - val_mse: 0.0027 - val_mean_absolute_error: 0.0418 - val_r2_keras: 0.9804
# Epoch 17/20
# 200/200 [==============================] - 26s 129ms/step - loss: 0.0027 - mse: 0.0027 - mean_absolute_error: 0.0414 - r2_keras: 0.9807 - val_loss: 0.0024 - val_mse: 0.0024 - val_mean_absolute_error: 0.0403 - val_r2_keras: 0.9817
# Epoch 18/20
# 200/200 [==============================] - 25s 123ms/step - loss: 0.0027 - mse: 0.0027 - mean_absolute_error: 0.0417 - r2_keras: 0.9803 - val_loss: 0.0027 - val_mse: 0.0027 - val_mean_absolute_error: 0.0426 - val_r2_keras: 0.9793
# Epoch 19/20
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0026 - mse: 0.0026 - mean_absolute_error: 0.0408 - r2_keras: 0.9811 - val_loss: 0.0028 - val_mse: 0.0028 - val_mean_absolute_error: 0.0428 - val_r2_keras: 0.9795
# Epoch 20/20
# 200/200 [==============================] - 26s 129ms/step - loss: 0.0026 - mse: 0.0026 - mean_absolute_error: 0.0412 - r2_keras: 0.9811 - val_loss: 0.0027 - val_mse: 0.0027 - val_mean_absolute_error: 0.0438 - val_r2_keras: 0.9791

# %%
show_history(history, metrics=['mse', 'mean_absolute_error','r2_keras'])

# %% [markdown]
# El score es muy bueno, obteniendo 98 en R2.
# Ahora vamos a predecir varios steps en adelante con el modelo.

# %%
# Número de pasos en adelante que vamos a predecir
steps_ahead = 30

series = generate_time_series(1, n_steps + steps_ahead)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new

# repetimos la predicción varias veces
for step_ahead in range(steps_ahead):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "bo-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "rx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# Probar en Google Colab:
# - Otros módulos recurrentes
# - Otras losses
# - Hacer predicciones multiples

# %% [markdown]
# ### Optimizadores, métricas y funciones loss
# En este apartado veremos distintas funciones para mejorar el entrenamiento de nuestra red neuronal

# %% [markdown]
# Sin duda uno de los mejores optimizadores es el Adam, veamos que score obtenemos entrenando con el.
# Probemos el optimizador Adam con un modelo convolucional sobre el dataset CIFAR10

# %%
# capas de la red
input = Input(shape=(32,32,3))
layer = Conv2D(filters=20, kernel_size=3, strides=1, padding='same', activation='relu')(input)
layer = MaxPooling2D((2, 2))(layer)
layer = Conv2D(filters=40, kernel_size=3, strides=1, padding='same', activation='relu')(layer)
layer = MaxPooling2D((2, 2))(layer)
layer = Conv2D(filters=80, kernel_size=3, strides=1, padding='same', activation='relu')(layer)
layer = MaxPooling2D((2, 2))(layer)
layer = Flatten()(layer)
layer = Dense(units=200, activation='relu')(layer)
output = Dense(units=10, activation='softmax')(layer)

# creamos el modelo
model = Model(inputs=input, outputs=output)
print(model.summary())

# optimizador
optimizer = Adam(learning_rate=0.001)

# función loss
loss = SparseCategoricalCrossentropy(from_logits=False)

# métrica
metrics = ['accuracy']

# compilamos el modelo
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(x=X_train_cifar10, y=y_train_cifar10, batch_size=30, epochs=20,
                    validation_data=(X_validation_cifar10, y_validation_cifar10))
# Out:
# Model: "functional_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 32, 32, 20)        560
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 16, 16, 20)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 16, 16, 40)        7240
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 8, 8, 40)          0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 8, 8, 80)          28880
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 4, 4, 80)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 200)               256200
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                2010
# =================================================================
# Total params: 294,890
# Trainable params: 294,890
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 1667/1667 [==============================] - 24s 14ms/step - loss: 1.3766 - accuracy: 0.5028 - val_loss: 1.1059 - val_accuracy: 0.6068
# Epoch 2/20
# 1667/1667 [==============================] - 23s 14ms/step - loss: 0.9857 - accuracy: 0.6524 - val_loss: 0.9283 - val_accuracy: 0.6727
# Epoch 3/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 0.8206 - accuracy: 0.7113 - val_loss: 0.9138 - val_accuracy: 0.6808
# Epoch 4/20
# 1667/1667 [==============================] - 26s 16ms/step - loss: 0.7126 - accuracy: 0.7512 - val_loss: 0.7851 - val_accuracy: 0.7277
# Epoch 5/20
# 1667/1667 [==============================] - 26s 16ms/step - loss: 0.6219 - accuracy: 0.7812 - val_loss: 0.7765 - val_accuracy: 0.7366
# Epoch 6/20
# 1667/1667 [==============================] - 26s 16ms/step - loss: 0.5408 - accuracy: 0.8092 - val_loss: 0.7887 - val_accuracy: 0.7370
# Epoch 7/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 0.4734 - accuracy: 0.8312 - val_loss: 0.8238 - val_accuracy: 0.7346
# Epoch 8/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 0.4069 - accuracy: 0.8556 - val_loss: 0.8870 - val_accuracy: 0.7253
# Epoch 9/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.3537 - accuracy: 0.8731 - val_loss: 0.8888 - val_accuracy: 0.7281
# Epoch 10/20
# 1667/1667 [==============================] - 27s 16ms/step - loss: 0.2936 - accuracy: 0.8945 - val_loss: 1.0327 - val_accuracy: 0.7127
# Epoch 11/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.2524 - accuracy: 0.9089 - val_loss: 1.0572 - val_accuracy: 0.7326
# Epoch 12/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.2118 - accuracy: 0.9251 - val_loss: 1.1067 - val_accuracy: 0.7297
# Epoch 13/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1890 - accuracy: 0.9318 - val_loss: 1.3227 - val_accuracy: 0.7164
# Epoch 14/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1638 - accuracy: 0.9401 - val_loss: 1.4072 - val_accuracy: 0.7248
# Epoch 15/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1563 - accuracy: 0.9443 - val_loss: 1.4500 - val_accuracy: 0.7267
# Epoch 16/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1359 - accuracy: 0.9519 - val_loss: 1.4674 - val_accuracy: 0.7227
# Epoch 17/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1281 - accuracy: 0.9545 - val_loss: 1.6920 - val_accuracy: 0.7110
# Epoch 18/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1251 - accuracy: 0.9555 - val_loss: 1.5878 - val_accuracy: 0.7292
# Epoch 19/20
# 1667/1667 [==============================] - 29s 17ms/step - loss: 0.1101 - accuracy: 0.9615 - val_loss: 1.6752 - val_accuracy: 0.7279
# Epoch 20/20
# 1667/1667 [==============================] - 28s 17ms/step - loss: 0.1155 - accuracy: 0.9595 - val_loss: 1.7906 - val_accuracy: 0.7202

# %% [markdown]
# Hemos obtenido un 72% de accuracy en la epoch 4! en el dataset CIFAR 10
# Con este optimizador la convergencia del modelo es muy rápida.
# Además podemos apreciar en la próxima gráfica que se está generando overfiting.

# %%
show_history(history)

# %% [markdown]
# Ahora vamos a entrenar con una custom loss.

# %%
# construimos una función loss que es una suma ponderada del MSE y el R2
def custom_loss(alpha):
    def custom_loss_fun(y_true, y_pred):
        return r2_keras(y_true, y_pred)*alpha + MSE(y_true, y_pred)
    return custom_loss_fun

# %% [markdown]
# Utilizamos el dataset de consumo de combustible

# %%
# capas de la red
input = Input(shape=(6))
x = input
for i in range(3):
    x = layers.Dense(units=50, activation='relu')(x)
output = layers.Dense(units=1, activation=None)(x)

# creamos el modelo
model = Model(inputs=input, outputs=output)
print(model.summary())

from aux_func import r2_keras
# compilamos el modelo
model.compile(optimizer='Adam', loss=custom_loss(0.1), metrics=['mse', r2_keras])
history = model.fit(x=X_train_consumo, y=y_train_consumo, batch_size=50, epochs=200,validation_data=(X_validation_consumo, y_validation_consumo))
# Out:
# Model: "functional_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 6)]               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 50)                350
# _________________________________________________________________
# dense_57 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_58 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_59 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 5,501
# Trainable params: 5,501
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 7/7 [==============================] - 0s 17ms/step - loss: 580.0611 - mse: 580.9548 - r2_keras: -8.8517 - val_loss: 603.3978 - val_mse: 604.4809 - val_r2_keras: -12.0439
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 559.5112 - mse: 560.3741 - r2_keras: -8.5725 - val_loss: 578.3134 - val_mse: 579.3477 - val_r2_keras: -11.5240
# Epoch 3/200
# 7/7 [==============================] - 0s 3ms/step - loss: 532.4013 - mse: 533.2124 - r2_keras: -8.3596 - val_loss: 543.8740 - val_mse: 544.8412 - val_r2_keras: -10.8050
# Epoch 4/200
# 7/7 [==============================] - 0s 3ms/step - loss: 495.4607 - mse: 496.2159 - r2_keras: -7.3774 - val_loss: 496.6003 - val_mse: 497.4753 - val_r2_keras: -9.8101
# Epoch 5/200
# 7/7 [==============================] - 0s 3ms/step - loss: 445.1896 - mse: 445.8603 - r2_keras: -6.8421 - val_loss: 432.9554 - val_mse: 433.7060 - val_r2_keras: -8.4619
# Epoch 6/200
# 7/7 [==============================] - 0s 3ms/step - loss: 378.7568 - mse: 379.3060 - r2_keras: -5.4823 - val_loss: 351.8829 - val_mse: 352.4747 - val_r2_keras: -6.7197
# Epoch 7/200
# 7/7 [==============================] - 0s 3ms/step - loss: 298.1895 - mse: 298.6205 - r2_keras: -4.1182 - val_loss: 257.9573 - val_mse: 258.3642 - val_r2_keras: -4.6493
# Epoch 8/200
# 7/7 [==============================] - 0s 3ms/step - loss: 211.0889 - mse: 211.3655 - r2_keras: -2.5636 - val_loss: 160.9553 - val_mse: 161.1703 - val_r2_keras: -2.4505
# Epoch 9/200
# 7/7 [==============================] - 0s 3ms/step - loss: 126.4370 - mse: 126.5535 - r2_keras: -1.0908 - val_loss: 79.3600 - val_mse: 79.4132 - val_r2_keras: -0.5836
# Epoch 10/200
# 7/7 [==============================] - 0s 3ms/step - loss: 66.5625 - mse: 66.5781 - r2_keras: -0.0894 - val_loss: 37.6527 - val_mse: 37.6236 - val_r2_keras: 0.3550
# Epoch 11/200
# 7/7 [==============================] - 0s 3ms/step - loss: 44.3487 - mse: 44.3273 - r2_keras: 0.2334 - val_loss: 35.0795 - val_mse: 35.0457 - val_r2_keras: 0.3868
# Epoch 12/200
# 7/7 [==============================] - 0s 3ms/step - loss: 42.6758 - mse: 42.6513 - r2_keras: 0.2318 - val_loss: 32.5558 - val_mse: 32.5176 - val_r2_keras: 0.4124
# Epoch 13/200
# 7/7 [==============================] - 0s 3ms/step - loss: 36.1789 - mse: 36.1429 - r2_keras: 0.3879 - val_loss: 26.2953 - val_mse: 26.2449 - val_r2_keras: 0.5418
# Epoch 14/200
# 7/7 [==============================] - 0s 3ms/step - loss: 31.5496 - mse: 31.5062 - r2_keras: 0.4702 - val_loss: 23.3174 - val_mse: 23.2611 - val_r2_keras: 0.6054
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 28.4415 - mse: 28.3906 - r2_keras: 0.5198 - val_loss: 21.5737 - val_mse: 21.5141 - val_r2_keras: 0.6388
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 25.7230 - mse: 25.6669 - r2_keras: 0.5687 - val_loss: 20.4995 - val_mse: 20.4379 - val_r2_keras: 0.6527
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 23.9403 - mse: 23.8839 - r2_keras: 0.4842 - val_loss: 19.7990 - val_mse: 19.7362 - val_r2_keras: 0.6584
# Epoch 18/200
# 7/7 [==============================] - 0s 3ms/step - loss: 22.5252 - mse: 22.4668 - r2_keras: 0.5478 - val_loss: 18.6673 - val_mse: 18.6024 - val_r2_keras: 0.6740
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 21.0032 - mse: 20.9400 - r2_keras: 0.6571 - val_loss: 17.3708 - val_mse: 17.3035 - val_r2_keras: 0.6978
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 20.0101 - mse: 19.9468 - r2_keras: 0.6422 - val_loss: 16.4844 - val_mse: 16.4154 - val_r2_keras: 0.7144
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 18.9680 - mse: 18.9017 - r2_keras: 0.6865 - val_loss: 15.8142 - val_mse: 15.7440 - val_r2_keras: 0.7196
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 17.9968 - mse: 17.9286 - r2_keras: 0.6918 - val_loss: 15.3074 - val_mse: 15.2363 - val_r2_keras: 0.7226
# Epoch 23/200
# 7/7 [==============================] - 0s 3ms/step - loss: 17.2890 - mse: 17.2202 - r2_keras: 0.6977 - val_loss: 14.7224 - val_mse: 14.6503 - val_r2_keras: 0.7310
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 16.5549 - mse: 16.4828 - r2_keras: 0.7227 - val_loss: 14.2472 - val_mse: 14.1742 - val_r2_keras: 0.7389
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 16.0400 - mse: 15.9670 - r2_keras: 0.7398 - val_loss: 13.6827 - val_mse: 13.6086 - val_r2_keras: 0.7520
# Epoch 26/200
# 7/7 [==============================] - 0s 3ms/step - loss: 15.4575 - mse: 15.3857 - r2_keras: 0.6458 - val_loss: 13.3822 - val_mse: 13.3076 - val_r2_keras: 0.7524
# Epoch 27/200
# 7/7 [==============================] - 0s 3ms/step - loss: 14.9312 - mse: 14.8569 - r2_keras: 0.7644 - val_loss: 13.1520 - val_mse: 13.0770 - val_r2_keras: 0.7562
# Epoch 28/200
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5524 - mse: 14.4771 - r2_keras: 0.7672 - val_loss: 12.8344 - val_mse: 12.7587 - val_r2_keras: 0.7609
# Epoch 29/200
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1039 - mse: 14.0282 - r2_keras: 0.7670 - val_loss: 12.7511 - val_mse: 12.6755 - val_r2_keras: 0.7554
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 13.7665 - mse: 13.6924 - r2_keras: 0.7344 - val_loss: 12.3828 - val_mse: 12.3064 - val_r2_keras: 0.7621
# Epoch 31/200
# 7/7 [==============================] - 0s 3ms/step - loss: 13.4964 - mse: 13.4207 - r2_keras: 0.7739 - val_loss: 11.8486 - val_mse: 11.7711 - val_r2_keras: 0.7779
# Epoch 32/200
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1609 - mse: 13.0834 - r2_keras: 0.7823 - val_loss: 11.7842 - val_mse: 11.7066 - val_r2_keras: 0.7734
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8746 - mse: 12.7965 - r2_keras: 0.7661 - val_loss: 11.7346 - val_mse: 11.6570 - val_r2_keras: 0.7718
# Epoch 34/200
# 7/7 [==============================] - 0s 3ms/step - loss: 12.6392 - mse: 12.5620 - r2_keras: 0.7455 - val_loss: 11.4510 - val_mse: 11.3728 - val_r2_keras: 0.7805
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 12.3634 - mse: 12.2852 - r2_keras: 0.7697 - val_loss: 11.4346 - val_mse: 11.3564 - val_r2_keras: 0.7784
# Epoch 36/200
# 7/7 [==============================] - 0s 3ms/step - loss: 12.1519 - mse: 12.0741 - r2_keras: 0.7810 - val_loss: 11.4693 - val_mse: 11.3913 - val_r2_keras: 0.7747
# Epoch 37/200
# 7/7 [==============================] - 0s 3ms/step - loss: 11.9692 - mse: 11.8900 - r2_keras: 0.7847 - val_loss: 11.1717 - val_mse: 11.0930 - val_r2_keras: 0.7854
# Epoch 38/200
# 7/7 [==============================] - 0s 3ms/step - loss: 11.6922 - mse: 11.6121 - r2_keras: 0.8091 - val_loss: 11.1499 - val_mse: 11.0712 - val_r2_keras: 0.7814
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 11.4301 - mse: 11.3496 - r2_keras: 0.7874 - val_loss: 11.2138 - val_mse: 11.1353 - val_r2_keras: 0.7764
# Epoch 40/200
# 7/7 [==============================] - 0s 3ms/step - loss: 11.2972 - mse: 11.2164 - r2_keras: 0.7976 - val_loss: 11.0021 - val_mse: 10.9233 - val_r2_keras: 0.7799
# Epoch 41/200
# 7/7 [==============================] - 0s 3ms/step - loss: 11.0054 - mse: 10.9243 - r2_keras: 0.8148 - val_loss: 10.4941 - val_mse: 10.4141 - val_r2_keras: 0.7953
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 11.0485 - mse: 10.9683 - r2_keras: 0.8144 - val_loss: 10.2227 - val_mse: 10.1422 - val_r2_keras: 0.8027
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6505 - mse: 10.5694 - r2_keras: 0.8052 - val_loss: 10.3160 - val_mse: 10.2358 - val_r2_keras: 0.7946
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6073 - mse: 10.5250 - r2_keras: 0.8049 - val_loss: 10.3105 - val_mse: 10.2303 - val_r2_keras: 0.7911
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3277 - mse: 10.2452 - r2_keras: 0.8282 - val_loss: 9.7644 - val_mse: 9.6830 - val_r2_keras: 0.8093
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3263 - mse: 10.2444 - r2_keras: 0.7966 - val_loss: 9.6577 - val_mse: 9.5761 - val_r2_keras: 0.8137
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 10.1538 - mse: 10.0723 - r2_keras: 0.7616 - val_loss: 9.7868 - val_mse: 9.7056 - val_r2_keras: 0.8033
# Epoch 48/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.9925 - mse: 9.9098 - r2_keras: 0.8376 - val_loss: 9.6453 - val_mse: 9.5639 - val_r2_keras: 0.8058
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.7886 - mse: 9.7048 - r2_keras: 0.8499 - val_loss: 9.4020 - val_mse: 9.3200 - val_r2_keras: 0.8123
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.7547 - mse: 9.6714 - r2_keras: 0.8238 - val_loss: 9.2865 - val_mse: 9.2042 - val_r2_keras: 0.8162
# Epoch 51/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.5398 - mse: 9.4558 - r2_keras: 0.8320 - val_loss: 9.4000 - val_mse: 9.3180 - val_r2_keras: 0.8109
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.6347 - mse: 9.5515 - r2_keras: 0.8260 - val_loss: 9.9579 - val_mse: 9.8771 - val_r2_keras: 0.7915
# Epoch 53/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.4389 - mse: 9.3546 - r2_keras: 0.8380 - val_loss: 9.2660 - val_mse: 9.1837 - val_r2_keras: 0.8142
# Epoch 54/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.2755 - mse: 9.1910 - r2_keras: 0.8460 - val_loss: 9.2046 - val_mse: 9.1222 - val_r2_keras: 0.8147
# Epoch 55/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.1998 - mse: 9.1156 - r2_keras: 0.8425 - val_loss: 9.1687 - val_mse: 9.0863 - val_r2_keras: 0.8137
# Epoch 56/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.0548 - mse: 8.9703 - r2_keras: 0.8399 - val_loss: 8.8920 - val_mse: 8.8091 - val_r2_keras: 0.8214
# Epoch 57/200
# 7/7 [==============================] - 0s 3ms/step - loss: 9.0205 - mse: 8.9370 - r2_keras: 0.8388 - val_loss: 8.6192 - val_mse: 8.5356 - val_r2_keras: 0.8299
# Epoch 58/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.9258 - mse: 8.8414 - r2_keras: 0.8521 - val_loss: 8.7987 - val_mse: 8.7156 - val_r2_keras: 0.8222
# Epoch 59/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.8322 - mse: 8.7480 - r2_keras: 0.8356 - val_loss: 8.7973 - val_mse: 8.7142 - val_r2_keras: 0.8210
# Epoch 60/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.7829 - mse: 8.6980 - r2_keras: 0.8545 - val_loss: 8.4738 - val_mse: 8.3900 - val_r2_keras: 0.8312
# Epoch 61/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.6597 - mse: 8.5744 - r2_keras: 0.8533 - val_loss: 8.4900 - val_mse: 8.4063 - val_r2_keras: 0.8290
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.6063 - mse: 8.5217 - r2_keras: 0.8228 - val_loss: 8.9006 - val_mse: 8.8178 - val_r2_keras: 0.8143
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.4777 - mse: 8.3919 - r2_keras: 0.8491 - val_loss: 8.4343 - val_mse: 8.3504 - val_r2_keras: 0.8290
# Epoch 64/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.4427 - mse: 8.3573 - r2_keras: 0.8610 - val_loss: 8.3052 - val_mse: 8.2211 - val_r2_keras: 0.8341
# Epoch 65/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.3941 - mse: 8.3085 - r2_keras: 0.8592 - val_loss: 8.3385 - val_mse: 8.2545 - val_r2_keras: 0.8317
# Epoch 66/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.2498 - mse: 8.1641 - r2_keras: 0.8529 - val_loss: 8.3656 - val_mse: 8.2817 - val_r2_keras: 0.8293
# Epoch 67/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1990 - mse: 8.1132 - r2_keras: 0.8662 - val_loss: 8.3185 - val_mse: 8.2345 - val_r2_keras: 0.8302
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1427 - mse: 8.0564 - r2_keras: 0.8612 - val_loss: 8.3037 - val_mse: 8.2197 - val_r2_keras: 0.8308
# Epoch 69/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1505 - mse: 8.0640 - r2_keras: 0.8679 - val_loss: 8.1709 - val_mse: 8.0865 - val_r2_keras: 0.8347
# Epoch 70/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.0113 - mse: 7.9252 - r2_keras: 0.8671 - val_loss: 8.1409 - val_mse: 8.0566 - val_r2_keras: 0.8341
# Epoch 71/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.9899 - mse: 7.9039 - r2_keras: 0.8571 - val_loss: 8.0712 - val_mse: 7.9867 - val_r2_keras: 0.8352
# Epoch 72/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1906 - mse: 8.1046 - r2_keras: 0.8640 - val_loss: 8.5148 - val_mse: 8.4313 - val_r2_keras: 0.8205
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 8.0524 - mse: 7.9658 - r2_keras: 0.8718 - val_loss: 7.7417 - val_mse: 7.6565 - val_r2_keras: 0.8450
# Epoch 74/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.8840 - mse: 7.7983 - r2_keras: 0.8345 - val_loss: 7.8293 - val_mse: 7.7443 - val_r2_keras: 0.8421
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.8142 - mse: 7.7276 - r2_keras: 0.8727 - val_loss: 7.7885 - val_mse: 7.7035 - val_r2_keras: 0.8419
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.7747 - mse: 7.6880 - r2_keras: 0.8790 - val_loss: 7.8726 - val_mse: 7.7878 - val_r2_keras: 0.8383
# Epoch 77/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.7306 - mse: 7.6436 - r2_keras: 0.8777 - val_loss: 7.7977 - val_mse: 7.7127 - val_r2_keras: 0.8409
# Epoch 78/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.7198 - mse: 7.6328 - r2_keras: 0.8687 - val_loss: 7.5669 - val_mse: 7.4814 - val_r2_keras: 0.8484
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.6682 - mse: 7.5817 - r2_keras: 0.8648 - val_loss: 7.6051 - val_mse: 7.5197 - val_r2_keras: 0.8459
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5954 - mse: 7.5081 - r2_keras: 0.8789 - val_loss: 7.8250 - val_mse: 7.7400 - val_r2_keras: 0.8390
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5554 - mse: 7.4684 - r2_keras: 0.8645 - val_loss: 7.8287 - val_mse: 7.7438 - val_r2_keras: 0.8391
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5306 - mse: 7.4434 - r2_keras: 0.8672 - val_loss: 7.8112 - val_mse: 7.7263 - val_r2_keras: 0.8398
# Epoch 83/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5154 - mse: 7.4284 - r2_keras: 0.8733 - val_loss: 7.7330 - val_mse: 7.6478 - val_r2_keras: 0.8428
# Epoch 84/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4998 - mse: 7.4130 - r2_keras: 0.8696 - val_loss: 7.7394 - val_mse: 7.6542 - val_r2_keras: 0.8423
# Epoch 85/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4597 - mse: 7.3725 - r2_keras: 0.8783 - val_loss: 7.7583 - val_mse: 7.6732 - val_r2_keras: 0.8414
# Epoch 86/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4738 - mse: 7.3864 - r2_keras: 0.8557 - val_loss: 7.5112 - val_mse: 7.4256 - val_r2_keras: 0.8482
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.3482 - mse: 7.2613 - r2_keras: 0.8549 - val_loss: 7.9420 - val_mse: 7.8573 - val_r2_keras: 0.8340
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5289 - mse: 7.4414 - r2_keras: 0.8815 - val_loss: 7.8605 - val_mse: 7.7757 - val_r2_keras: 0.8361
# Epoch 89/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.3418 - mse: 7.2545 - r2_keras: 0.8745 - val_loss: 7.5136 - val_mse: 7.4280 - val_r2_keras: 0.8477
# Epoch 90/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4708 - mse: 7.3837 - r2_keras: 0.8677 - val_loss: 7.5423 - val_mse: 7.4568 - val_r2_keras: 0.8465
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.6516 - mse: 7.5645 - r2_keras: 0.8741 - val_loss: 8.3104 - val_mse: 8.2265 - val_r2_keras: 0.8223
# Epoch 92/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4621 - mse: 7.3748 - r2_keras: 0.8760 - val_loss: 7.6176 - val_mse: 7.5322 - val_r2_keras: 0.8431
# Epoch 93/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4547 - mse: 7.3675 - r2_keras: 0.8672 - val_loss: 7.3960 - val_mse: 7.3102 - val_r2_keras: 0.8504
# Epoch 94/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.4130 - mse: 7.3257 - r2_keras: 0.8814 - val_loss: 7.7687 - val_mse: 7.6837 - val_r2_keras: 0.8369
# Epoch 95/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2849 - mse: 7.1973 - r2_keras: 0.8775 - val_loss: 7.3975 - val_mse: 7.3117 - val_r2_keras: 0.8479
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2752 - mse: 7.1876 - r2_keras: 0.8640 - val_loss: 7.2366 - val_mse: 7.1504 - val_r2_keras: 0.8545
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2020 - mse: 7.1142 - r2_keras: 0.8824 - val_loss: 7.6290 - val_mse: 7.5437 - val_r2_keras: 0.8432
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2492 - mse: 7.1618 - r2_keras: 0.8665 - val_loss: 7.7039 - val_mse: 7.6187 - val_r2_keras: 0.8397
# Epoch 99/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2014 - mse: 7.1138 - r2_keras: 0.8793 - val_loss: 7.7236 - val_mse: 7.6385 - val_r2_keras: 0.8378
# Epoch 100/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.1762 - mse: 7.0883 - r2_keras: 0.8755 - val_loss: 7.4553 - val_mse: 7.3696 - val_r2_keras: 0.8461
# Epoch 101/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.1515 - mse: 7.0636 - r2_keras: 0.8761 - val_loss: 7.4911 - val_mse: 7.4055 - val_r2_keras: 0.8459
# Epoch 102/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.1686 - mse: 7.0808 - r2_keras: 0.8703 - val_loss: 7.9843 - val_mse: 7.8998 - val_r2_keras: 0.8300
# Epoch 103/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.0988 - mse: 7.0104 - r2_keras: 0.8895 - val_loss: 7.2487 - val_mse: 7.1625 - val_r2_keras: 0.8539
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.1547 - mse: 7.0666 - r2_keras: 0.8836 - val_loss: 7.3045 - val_mse: 7.2185 - val_r2_keras: 0.8510
# Epoch 105/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.0796 - mse: 6.9914 - r2_keras: 0.8761 - val_loss: 7.5922 - val_mse: 7.5069 - val_r2_keras: 0.8404
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.0197 - mse: 6.9315 - r2_keras: 0.8781 - val_loss: 7.3404 - val_mse: 7.2546 - val_r2_keras: 0.8485
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.0295 - mse: 6.9417 - r2_keras: 0.8818 - val_loss: 7.2267 - val_mse: 7.1406 - val_r2_keras: 0.8532
# Epoch 108/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.9904 - mse: 6.9022 - r2_keras: 0.8876 - val_loss: 7.2785 - val_mse: 7.1925 - val_r2_keras: 0.8487
# Epoch 109/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.1288 - mse: 7.0414 - r2_keras: 0.8557 - val_loss: 7.5011 - val_mse: 7.4155 - val_r2_keras: 0.8421
# Epoch 110/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2028 - mse: 7.1149 - r2_keras: 0.8791 - val_loss: 6.9437 - val_mse: 6.8569 - val_r2_keras: 0.8623
# Epoch 111/200
# 7/7 [==============================] - 0s 3ms/step - loss: 7.0728 - mse: 6.9848 - r2_keras: 0.8858 - val_loss: 7.4596 - val_mse: 7.3740 - val_r2_keras: 0.8453
# Epoch 112/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.9984 - mse: 6.9102 - r2_keras: 0.8844 - val_loss: 7.2793 - val_mse: 7.1933 - val_r2_keras: 0.8493
# Epoch 113/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.8861 - mse: 6.7977 - r2_keras: 0.8858 - val_loss: 7.2258 - val_mse: 7.1397 - val_r2_keras: 0.8524
# Epoch 114/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.9026 - mse: 6.8143 - r2_keras: 0.8877 - val_loss: 7.7845 - val_mse: 7.6995 - val_r2_keras: 0.8348
# Epoch 115/200
# 7/7 [==============================] - 0s 2ms/step - loss: 7.0048 - mse: 6.9166 - r2_keras: 0.8782 - val_loss: 7.3005 - val_mse: 7.2146 - val_r2_keras: 0.8485
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.9188 - mse: 6.8304 - r2_keras: 0.8834 - val_loss: 7.1192 - val_mse: 7.0329 - val_r2_keras: 0.8547
# Epoch 117/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.8189 - mse: 6.7302 - r2_keras: 0.8946 - val_loss: 7.3634 - val_mse: 7.2776 - val_r2_keras: 0.8467
# Epoch 118/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7956 - mse: 6.7074 - r2_keras: 0.8916 - val_loss: 7.0127 - val_mse: 6.9262 - val_r2_keras: 0.8561
# Epoch 119/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7887 - mse: 6.7004 - r2_keras: 0.8912 - val_loss: 6.9680 - val_mse: 6.8814 - val_r2_keras: 0.8569
# Epoch 120/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7840 - mse: 6.6954 - r2_keras: 0.8902 - val_loss: 7.0654 - val_mse: 6.9790 - val_r2_keras: 0.8539
# Epoch 121/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7590 - mse: 6.6709 - r2_keras: 0.8642 - val_loss: 6.9434 - val_mse: 6.8567 - val_r2_keras: 0.8568
# Epoch 122/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.8285 - mse: 6.7403 - r2_keras: 0.8794 - val_loss: 6.7169 - val_mse: 6.6297 - val_r2_keras: 0.8645
# Epoch 123/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7713 - mse: 6.6831 - r2_keras: 0.8651 - val_loss: 6.8925 - val_mse: 6.8057 - val_r2_keras: 0.8593
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7076 - mse: 6.6191 - r2_keras: 0.8844 - val_loss: 6.9310 - val_mse: 6.8443 - val_r2_keras: 0.8574
# Epoch 125/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.6971 - mse: 6.6084 - r2_keras: 0.8940 - val_loss: 6.8529 - val_mse: 6.7661 - val_r2_keras: 0.8594
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.6692 - mse: 6.5804 - r2_keras: 0.8952 - val_loss: 6.9731 - val_mse: 6.8865 - val_r2_keras: 0.8561
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.6775 - mse: 6.5891 - r2_keras: 0.8917 - val_loss: 7.0815 - val_mse: 6.9952 - val_r2_keras: 0.8523
# Epoch 128/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7581 - mse: 6.6696 - r2_keras: 0.8920 - val_loss: 7.0323 - val_mse: 6.9458 - val_r2_keras: 0.8533
# Epoch 129/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.6142 - mse: 6.5264 - r2_keras: 0.8777 - val_loss: 6.7064 - val_mse: 6.6192 - val_r2_keras: 0.8647
# Epoch 130/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7570 - mse: 6.6685 - r2_keras: 0.8884 - val_loss: 6.8392 - val_mse: 6.7523 - val_r2_keras: 0.8601
# Epoch 131/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.6398 - mse: 6.5515 - r2_keras: 0.8887 - val_loss: 7.0850 - val_mse: 6.9986 - val_r2_keras: 0.8521
# Epoch 132/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5838 - mse: 6.4955 - r2_keras: 0.8688 - val_loss: 6.8564 - val_mse: 6.7696 - val_r2_keras: 0.8594
# Epoch 133/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.6174 - mse: 6.5282 - r2_keras: 0.8869 - val_loss: 6.7266 - val_mse: 6.6394 - val_r2_keras: 0.8638
# Epoch 134/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5739 - mse: 6.4851 - r2_keras: 0.8962 - val_loss: 7.0385 - val_mse: 6.9521 - val_r2_keras: 0.8532
# Epoch 135/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5214 - mse: 6.4324 - r2_keras: 0.8929 - val_loss: 7.0366 - val_mse: 6.9502 - val_r2_keras: 0.8530
# Epoch 136/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5953 - mse: 6.5065 - r2_keras: 0.8798 - val_loss: 6.8472 - val_mse: 6.7604 - val_r2_keras: 0.8581
# Epoch 137/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5313 - mse: 6.4426 - r2_keras: 0.8869 - val_loss: 6.6989 - val_mse: 6.6117 - val_r2_keras: 0.8632
# Epoch 138/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5324 - mse: 6.4435 - r2_keras: 0.8853 - val_loss: 6.6360 - val_mse: 6.5487 - val_r2_keras: 0.8645
# Epoch 139/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5350 - mse: 6.4459 - r2_keras: 0.8977 - val_loss: 7.1385 - val_mse: 7.0522 - val_r2_keras: 0.8495
# Epoch 140/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5312 - mse: 6.4424 - r2_keras: 0.8947 - val_loss: 6.7835 - val_mse: 6.6965 - val_r2_keras: 0.8599
# Epoch 141/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4818 - mse: 6.3923 - r2_keras: 0.9009 - val_loss: 6.9567 - val_mse: 6.8701 - val_r2_keras: 0.8551
# Epoch 142/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4500 - mse: 6.3610 - r2_keras: 0.8940 - val_loss: 6.9210 - val_mse: 6.8343 - val_r2_keras: 0.8574
# Epoch 143/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4130 - mse: 6.3239 - r2_keras: 0.8982 - val_loss: 7.1896 - val_mse: 7.1035 - val_r2_keras: 0.8485
# Epoch 144/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4060 - mse: 6.3168 - r2_keras: 0.8948 - val_loss: 6.8157 - val_mse: 6.7287 - val_r2_keras: 0.8602
# Epoch 145/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4115 - mse: 6.3222 - r2_keras: 0.8949 - val_loss: 6.9031 - val_mse: 6.8163 - val_r2_keras: 0.8570
# Epoch 146/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3421 - mse: 6.2525 - r2_keras: 0.8981 - val_loss: 7.0146 - val_mse: 6.9281 - val_r2_keras: 0.8529
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3733 - mse: 6.2839 - r2_keras: 0.8905 - val_loss: 6.6606 - val_mse: 6.5734 - val_r2_keras: 0.8633
# Epoch 148/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3803 - mse: 6.2911 - r2_keras: 0.8937 - val_loss: 6.8281 - val_mse: 6.7412 - val_r2_keras: 0.8597
# Epoch 149/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4283 - mse: 6.3391 - r2_keras: 0.8908 - val_loss: 7.1228 - val_mse: 7.0365 - val_r2_keras: 0.8501
# Epoch 150/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3927 - mse: 6.3033 - r2_keras: 0.8955 - val_loss: 6.8827 - val_mse: 6.7959 - val_r2_keras: 0.8572
# Epoch 151/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3036 - mse: 6.2144 - r2_keras: 0.8982 - val_loss: 6.7556 - val_mse: 6.6686 - val_r2_keras: 0.8619
# Epoch 152/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3613 - mse: 6.2720 - r2_keras: 0.8965 - val_loss: 6.7431 - val_mse: 6.6560 - val_r2_keras: 0.8617
# Epoch 153/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3442 - mse: 6.2552 - r2_keras: 0.8971 - val_loss: 6.9630 - val_mse: 6.8764 - val_r2_keras: 0.8546
# Epoch 154/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3746 - mse: 6.2852 - r2_keras: 0.8925 - val_loss: 6.6844 - val_mse: 6.5973 - val_r2_keras: 0.8627
# Epoch 155/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4767 - mse: 6.3875 - r2_keras: 0.8884 - val_loss: 6.9424 - val_mse: 6.8558 - val_r2_keras: 0.8544
# Epoch 156/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2618 - mse: 6.1725 - r2_keras: 0.8817 - val_loss: 6.6273 - val_mse: 6.5400 - val_r2_keras: 0.8631
# Epoch 157/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3296 - mse: 6.2402 - r2_keras: 0.9008 - val_loss: 6.7024 - val_mse: 6.6153 - val_r2_keras: 0.8613
# Epoch 158/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2146 - mse: 6.1253 - r2_keras: 0.9004 - val_loss: 6.9458 - val_mse: 6.8592 - val_r2_keras: 0.8539
# Epoch 159/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2326 - mse: 6.1431 - r2_keras: 0.8949 - val_loss: 6.8995 - val_mse: 6.8128 - val_r2_keras: 0.8557
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2276 - mse: 6.1381 - r2_keras: 0.8961 - val_loss: 6.7632 - val_mse: 6.6762 - val_r2_keras: 0.8597
# Epoch 161/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2464 - mse: 6.1573 - r2_keras: 0.8814 - val_loss: 6.8155 - val_mse: 6.7287 - val_r2_keras: 0.8579
# Epoch 162/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1978 - mse: 6.1087 - r2_keras: 0.8977 - val_loss: 6.7900 - val_mse: 6.7031 - val_r2_keras: 0.8588
# Epoch 163/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1631 - mse: 6.0735 - r2_keras: 0.8963 - val_loss: 6.6798 - val_mse: 6.5926 - val_r2_keras: 0.8623
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2369 - mse: 6.1481 - r2_keras: 0.8937 - val_loss: 6.8930 - val_mse: 6.8063 - val_r2_keras: 0.8563
# Epoch 165/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2777 - mse: 6.1887 - r2_keras: 0.8824 - val_loss: 7.0453 - val_mse: 6.9589 - val_r2_keras: 0.8502
# Epoch 166/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1864 - mse: 6.0972 - r2_keras: 0.8914 - val_loss: 6.5055 - val_mse: 6.4180 - val_r2_keras: 0.8679
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2327 - mse: 6.1432 - r2_keras: 0.8968 - val_loss: 6.7486 - val_mse: 6.6616 - val_r2_keras: 0.8596
# Epoch 168/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1108 - mse: 6.0211 - r2_keras: 0.8991 - val_loss: 6.7077 - val_mse: 6.6206 - val_r2_keras: 0.8609
# Epoch 169/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3340 - mse: 6.2453 - r2_keras: 0.8929 - val_loss: 7.0136 - val_mse: 6.9271 - val_r2_keras: 0.8514
# Epoch 170/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0526 - mse: 5.9631 - r2_keras: 0.8897 - val_loss: 6.6430 - val_mse: 6.5557 - val_r2_keras: 0.8643
# Epoch 171/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.3213 - mse: 6.2320 - r2_keras: 0.8946 - val_loss: 6.6912 - val_mse: 6.6040 - val_r2_keras: 0.8623
# Epoch 172/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2105 - mse: 6.1208 - r2_keras: 0.8893 - val_loss: 7.1940 - val_mse: 7.1079 - val_r2_keras: 0.8459
# Epoch 173/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.2228 - mse: 6.1334 - r2_keras: 0.8848 - val_loss: 6.7753 - val_mse: 6.6883 - val_r2_keras: 0.8586
# Epoch 174/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1708 - mse: 6.0812 - r2_keras: 0.8918 - val_loss: 6.9220 - val_mse: 6.8354 - val_r2_keras: 0.8540
# Epoch 175/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0462 - mse: 5.9566 - r2_keras: 0.9012 - val_loss: 6.7441 - val_mse: 6.6571 - val_r2_keras: 0.8588
# Epoch 176/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0363 - mse: 5.9479 - r2_keras: 0.8855 - val_loss: 6.6396 - val_mse: 6.5523 - val_r2_keras: 0.8624
# Epoch 177/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0591 - mse: 5.9692 - r2_keras: 0.8974 - val_loss: 6.6844 - val_mse: 6.5972 - val_r2_keras: 0.8605
# Epoch 178/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0875 - mse: 5.9982 - r2_keras: 0.8885 - val_loss: 6.5274 - val_mse: 6.4400 - val_r2_keras: 0.8650
# Epoch 179/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0862 - mse: 5.9964 - r2_keras: 0.8982 - val_loss: 6.7823 - val_mse: 6.6954 - val_r2_keras: 0.8575
# Epoch 180/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1369 - mse: 6.0472 - r2_keras: 0.9007 - val_loss: 6.4346 - val_mse: 6.3470 - val_r2_keras: 0.8685
# Epoch 181/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9988 - mse: 5.9089 - r2_keras: 0.9022 - val_loss: 7.0374 - val_mse: 6.9510 - val_r2_keras: 0.8496
# Epoch 182/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1105 - mse: 6.0213 - r2_keras: 0.8930 - val_loss: 6.4178 - val_mse: 6.3301 - val_r2_keras: 0.8689
# Epoch 183/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0406 - mse: 5.9508 - r2_keras: 0.8868 - val_loss: 6.7922 - val_mse: 6.7053 - val_r2_keras: 0.8567
# Epoch 184/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1521 - mse: 6.0623 - r2_keras: 0.8912 - val_loss: 6.3687 - val_mse: 6.2809 - val_r2_keras: 0.8693
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1709 - mse: 6.0812 - r2_keras: 0.8959 - val_loss: 7.0021 - val_mse: 6.9157 - val_r2_keras: 0.8501
# Epoch 186/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1053 - mse: 6.0155 - r2_keras: 0.8988 - val_loss: 6.5233 - val_mse: 6.4358 - val_r2_keras: 0.8674
# Epoch 187/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0330 - mse: 5.9433 - r2_keras: 0.8771 - val_loss: 7.2874 - val_mse: 7.2015 - val_r2_keras: 0.8425
# Epoch 188/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9884 - mse: 5.8983 - r2_keras: 0.8992 - val_loss: 6.5213 - val_mse: 6.4338 - val_r2_keras: 0.8664
# Epoch 189/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9501 - mse: 5.8605 - r2_keras: 0.8994 - val_loss: 6.7708 - val_mse: 6.6838 - val_r2_keras: 0.8577
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9765 - mse: 5.8869 - r2_keras: 0.8833 - val_loss: 6.5991 - val_mse: 6.5118 - val_r2_keras: 0.8629
# Epoch 191/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9755 - mse: 5.8857 - r2_keras: 0.8967 - val_loss: 6.5105 - val_mse: 6.4230 - val_r2_keras: 0.8656
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0064 - mse: 5.9175 - r2_keras: 0.8878 - val_loss: 6.8992 - val_mse: 6.8126 - val_r2_keras: 0.8531
# Epoch 193/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0196 - mse: 5.9301 - r2_keras: 0.9009 - val_loss: 6.6393 - val_mse: 6.5521 - val_r2_keras: 0.8616
# Epoch 194/200
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0436 - mse: 5.9537 - r2_keras: 0.9021 - val_loss: 6.6047 - val_mse: 6.5174 - val_r2_keras: 0.8612
# Epoch 195/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9422 - mse: 5.8520 - r2_keras: 0.8966 - val_loss: 6.3544 - val_mse: 6.2666 - val_r2_keras: 0.8701
# Epoch 196/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.9920 - mse: 5.9021 - r2_keras: 0.8962 - val_loss: 6.8897 - val_mse: 6.8031 - val_r2_keras: 0.8527
# Epoch 197/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.8526 - mse: 5.7625 - r2_keras: 0.9022 - val_loss: 6.6319 - val_mse: 6.5447 - val_r2_keras: 0.8621
# Epoch 198/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.8985 - mse: 5.8087 - r2_keras: 0.8961 - val_loss: 6.6541 - val_mse: 6.5670 - val_r2_keras: 0.8608
# Epoch 199/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.8152 - mse: 5.7246 - r2_keras: 0.9103 - val_loss: 6.5506 - val_mse: 6.4632 - val_r2_keras: 0.8646
# Epoch 200/200
# 7/7 [==============================] - 0s 3ms/step - loss: 5.8557 - mse: 5.7660 - r2_keras: 0.8992 - val_loss: 6.7354 - val_mse: 6.6484 - val_r2_keras: 0.8578

# %% [markdown]
# En GoogleColab probar en el dataset de consumo:
# - Distintos optimizadores
# - Distintas funciones loss
# - Diseñar la función custom, beta*((y-y_pred)**4 + 2*abs(y-y_pred))+alpha*MSE(y_y_pred), y entrenar con ella.
#
# Con el Dataset de bitcoin:
# - Diseñar una red que prediga si va a subir o bajar y cuanto. Pista, hay que usar una custom loss.
